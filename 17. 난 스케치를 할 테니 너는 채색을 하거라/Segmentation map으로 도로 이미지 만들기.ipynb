# %% [markdown]
# # 프로젝트 조건

# %% [markdown]
# - 데이터에 한 가지 이상의 augmentation 방법을 적용하여 학습해 주세요.
# - (어떠한 방법을 사용했는지 적어주세요.)
# - 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 U-Net Generator를 사용해 주세요.
# - 모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운로드했던 "val" 폴더 내 이미지를 사용해 주세요.
# - 1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를 스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화해 주세요.
# - 모델을 충분히 학습하기에 시간이 부족할 수 있습니다. 적어도 10 epoch 이상 학습하며 중간 손실 값에 대한 로그를 남겨주세요. 좋은 결과를 얻기위해선 긴 학습 시간이 필요하므로 테스트 결과는 만족스럽지 않아도 괜찮습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 환경 설정

# %%
import numpy
import tensorflow

print(numpy.__version__)
print(tensorflow.__version__)
# Out:
# 1.21.4
# 2.6.0

# %% [markdown]
# 우선 cityscapes.zip 파일을 다운 받아 압축을 해제한다.

# %%
# !cd ~/aiffel/Segmentation map/data && unzip cityscapes.zip

# %% [markdown]
# # 1. 데이터 전처리

# %%
# 데이터 불러오기

import os

data_path = os.getenv('HOME')+'/aiffel/Segmentation_map/data/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %% [markdown]
# 총 1000개의 이미지가 있음을 확인할 수 있었다. <br>
# 이번에는 아래 코드를 이용해 각각의 이미지들이 어떻게 생겼는지 확인해본다. 학습용 데이터셋에서 임의로 6장을 선택하여 시각화한다.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %% [markdown]
# 하나의 이미지에 일반 사진 하나와 레이블 정보가 표시된 사진이 합쳐져 있음을 알 수 있다. <br>
#
# 이제 이미지 크기를 확인해본다.

# %%
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %% [markdown]
# (256, 512, 3)으로 확인되었다. 모델 학습에 사용할 데이터를 (256, 256, 3) 크기의 2개 이미지로 분할하여 사용하면 될 것으로 보인다.

# %%
# 이미지 나누기
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %% [markdown]
# 데이터의 다양성을 위해 회전과 반전을 이용한 여러 augmentation을 적용한다.

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]   

print("✅")
# Out:
# ✅

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %% [markdown]
# 이미지가 잘 양분되어 여러 augmentation이 적용된 것을 확인할 수 있다.

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# # 2. Generator 구성하기

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu= layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

print("✅")
# Out:
# ✅

# %%
class Encoder(layers.Layer):
    def __init__(self):
        super(Encoder, self).__init__()
        filters = [64,128,256,512,512,512,512,512]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i == 0:
                self.blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.blocks.append(EncodeBlock(f))
    
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
    
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
Encoder().get_summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encode_block (EncodeBlock)   (None, 128, 128, 64)      3072
# _________________________________________________________________
# encode_block_1 (EncodeBlock) (None, 64, 64, 128)       131584
# _________________________________________________________________
# encode_block_2 (EncodeBlock) (None, 32, 32, 256)       525312
# _________________________________________________________________
# encode_block_3 (EncodeBlock) (None, 16, 16, 512)       2099200
# _________________________________________________________________
# encode_block_4 (EncodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# encode_block_5 (EncodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# encode_block_6 (EncodeBlock) (None, 2, 2, 512)         4196352
# _________________________________________________________________
# encode_block_7 (EncodeBlock) (None, 1, 1, 512)         4196352
# =================================================================
# Total params: 19,544,576
# Trainable params: 19,538,688
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# 기존 실습을 따라 Generator와 Encoder를 구성하였다.

# %%
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

    
class Decoder(layers.Layer):
    def __init__(self):
        super(Decoder, self).__init__()
        filters = [512,512,512,512,256,128,64]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i < 3:
                self.blocks.append(DecodeBlock(f))
            else:
                self.blocks.append(DecodeBlock(f, dropout=False))
                
        self.blocks.append(layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False))
        
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
            
    def get_summary(self, input_shape=(1,1,512)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        
print("✅")
# Out:
# ✅

# %%
Decoder().get_summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1, 1, 512)]       0
# _________________________________________________________________
# decode_block (DecodeBlock)   (None, 2, 2, 512)         4196352
# _________________________________________________________________
# decode_block_1 (DecodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# decode_block_2 (DecodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# decode_block_3 (DecodeBlock) (None, 16, 16, 512)       4196352
# _________________________________________________________________
# decode_block_4 (DecodeBlock) (None, 32, 32, 256)       2098176
# _________________________________________________________________
# decode_block_5 (DecodeBlock) (None, 64, 64, 128)       524800
# _________________________________________________________________
# decode_block_6 (DecodeBlock) (None, 128, 128, 64)      131328
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 256, 256, 3)       3072
# =================================================================
# Total params: 19,542,784
# Trainable params: 19,537,792
# Non-trainable params: 4,992
# _________________________________________________________________

# %% [markdown]
# Decoder역시 잘 구성되었다.

# %%
class EncoderDecoderGenerator(Model):
    def __init__(self):
        super(EncoderDecoderGenerator, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def call(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
   
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        

EncoderDecoderGenerator().get_summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encoder_1 (Encoder)          (None, 1, 1, 512)         19544576
# _________________________________________________________________
# decoder_1 (Decoder)          (None, 256, 256, 3)       19542784
# =================================================================
# Total params: 39,087,360
# Trainable params: 39,076,480
# Non-trainable params: 10,880
# _________________________________________________________________

# %% [markdown]
# Encoder와 Decoder를 연결해 Generator를 만들었다. <br>
# Generator를 잘 작동시키기 위해서는 약 4000만 개의 파라미터를 잘 학습시켜야한다.

# %% [markdown]
# # 3. Generator 재구성하기 (Unet)

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)
    
print("✅")
# Out:
# ✅

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %% [markdown]
# 이전 실습에서 사용되었던 U-net Generator를 만들었다.

# %% [markdown]
# # 4. Discriminator 구성하기

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x 

print("✅")
# Out:
# ✅

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
print("✅")
# Out:
# ✅

# %%
Discriminator().get_summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 256, 256, 6)  0           input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %% [markdown]
# Discriminator를 만들었다. <Br>
# 시험 삼아 임의의 (256,256,3) 크기의 입력을 넣어 나오는 (30,30) 출력을 시각화해본다

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# # 5. 학습 및 테스트하기

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

print("✅")
# Out:
# ✅

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

print("✅")
# Out:
# ✅

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

print("✅")
# Out:
# ✅

# %%
EPOCHS = 10

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:0.8746
# L1_loss:0.3408
# Discriminator_loss:1.2091
#
# EPOCH[1] - STEP[20]
# Generator_loss:1.2994
# L1_loss:0.2761
# Discriminator_loss:1.3383
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.4482
# L1_loss:0.2828
# Discriminator_loss:0.9913
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.2722
# L1_loss:0.2600
# Discriminator_loss:0.7016
#
# EPOCH[1] - STEP[50]
# Generator_loss:1.5968
# L1_loss:0.2492
# Discriminator_loss:0.8548
#
# EPOCH[1] - STEP[60]
# Generator_loss:1.7214
# L1_loss:0.2154
# Discriminator_loss:0.7940
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.2316
# L1_loss:0.2487
# Discriminator_loss:0.9212
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.7978
# L1_loss:0.2270
# Discriminator_loss:0.8331
#
# EPOCH[1] - STEP[90]
# Generator_loss:1.6410
# L1_loss:0.2336
# Discriminator_loss:0.8761
#
# EPOCH[1] - STEP[100]
# Generator_loss:2.1051
# L1_loss:0.2155
# Discriminator_loss:0.9127
#
# EPOCH[1] - STEP[110]
# Generator_loss:1.2912
# L1_loss:0.2872
# Discriminator_loss:0.7975
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.0349
# L1_loss:0.2298
# Discriminator_loss:0.7648
#
# EPOCH[1] - STEP[130]
# Generator_loss:1.7007
# L1_loss:0.2453
# Discriminator_loss:0.6606
#
# EPOCH[1] - STEP[140]
# Generator_loss:2.1488
# L1_loss:0.2170
# Discriminator_loss:1.0002
#
# EPOCH[1] - STEP[150]
# Generator_loss:2.4733
# L1_loss:0.2209
# Discriminator_loss:0.6059
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.3107
# L1_loss:0.2527
# Discriminator_loss:0.7120
#
# EPOCH[1] - STEP[170]
# Generator_loss:1.1338
# L1_loss:0.2536
# Discriminator_loss:0.8350
#
# EPOCH[1] - STEP[180]
# Generator_loss:1.8967
# L1_loss:0.2398
# Discriminator_loss:0.3713
#
# EPOCH[1] - STEP[190]
# Generator_loss:1.2078
# L1_loss:0.2862
# Discriminator_loss:0.9071
#
# EPOCH[1] - STEP[200]
# Generator_loss:2.2301
# L1_loss:0.1819
# Discriminator_loss:1.1834
#
# EPOCH[1] - STEP[210]
# Generator_loss:2.6840
# L1_loss:0.2175
# Discriminator_loss:0.6188
#
# EPOCH[1] - STEP[220]
# Generator_loss:1.5891
# L1_loss:0.2217
# Discriminator_loss:0.4430
#
# EPOCH[1] - STEP[230]
# Generator_loss:1.8214
# L1_loss:0.2174
# Discriminator_loss:1.3341
#
# EPOCH[1] - STEP[240]
# Generator_loss:2.1283
# L1_loss:0.2553
# Discriminator_loss:0.6755
#
# EPOCH[1] - STEP[250]
# Generator_loss:1.1063
# L1_loss:0.2565
# Discriminator_loss:1.5655
#
# EPOCH[2] - STEP[10]
# Generator_loss:1.5499
# L1_loss:0.2356
# Discriminator_loss:0.7581
#
# EPOCH[2] - STEP[20]
# Generator_loss:2.6372
# L1_loss:0.2160
# Discriminator_loss:0.4733
#
# EPOCH[2] - STEP[30]
# Generator_loss:2.4236
# L1_loss:0.2033
# Discriminator_loss:0.7771
#
# EPOCH[2] - STEP[40]
# Generator_loss:1.9574
# L1_loss:0.2076
# Discriminator_loss:0.4003
#
# EPOCH[2] - STEP[50]
# Generator_loss:2.3360
# L1_loss:0.1836
# Discriminator_loss:0.3514
#
# EPOCH[2] - STEP[60]
# Generator_loss:2.8617
# L1_loss:0.2189
# Discriminator_loss:0.4178
#
# EPOCH[2] - STEP[70]
# Generator_loss:1.0380
# L1_loss:0.2402
# Discriminator_loss:0.7489
#
# EPOCH[2] - STEP[80]
# Generator_loss:2.0194
# L1_loss:0.1893
# Discriminator_loss:0.6853
#
# EPOCH[2] - STEP[90]
# Generator_loss:2.7444
# L1_loss:0.2126
# Discriminator_loss:0.4816
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.8919
# L1_loss:0.2266
# Discriminator_loss:0.3494
#
# EPOCH[2] - STEP[110]
# Generator_loss:1.0588
# L1_loss:0.2005
# Discriminator_loss:0.6190
#
# EPOCH[2] - STEP[120]
# Generator_loss:0.9738
# L1_loss:0.2586
# Discriminator_loss:0.9056
#
# EPOCH[2] - STEP[130]
# Generator_loss:1.2304
# L1_loss:0.2157
# Discriminator_loss:0.4880
#
# EPOCH[2] - STEP[140]
# Generator_loss:0.9400
# L1_loss:0.2073
# Discriminator_loss:0.7527
#
# EPOCH[2] - STEP[150]
# Generator_loss:1.2777
# L1_loss:0.2343
# Discriminator_loss:0.6220
#
# EPOCH[2] - STEP[160]
# Generator_loss:2.1786
# L1_loss:0.2032
# Discriminator_loss:0.4195
#
# EPOCH[2] - STEP[170]
# Generator_loss:1.0794
# L1_loss:0.2190
# Discriminator_loss:0.5736
#
# EPOCH[2] - STEP[180]
# Generator_loss:2.1730
# L1_loss:0.2144
# Discriminator_loss:0.4132
#
# EPOCH[2] - STEP[190]
# Generator_loss:3.4275
# L1_loss:0.1944
# Discriminator_loss:0.8218
#
# EPOCH[2] - STEP[200]
# Generator_loss:2.5570
# L1_loss:0.1886
# Discriminator_loss:0.5901
#
# EPOCH[2] - STEP[210]
# Generator_loss:2.0318
# L1_loss:0.1951
# Discriminator_loss:0.6340
#
# EPOCH[2] - STEP[220]
# Generator_loss:2.0941
# L1_loss:0.2210
# Discriminator_loss:0.3477
#
# EPOCH[2] - STEP[230]
# Generator_loss:2.1763
# L1_loss:0.2115
# Discriminator_loss:0.6349
#
# EPOCH[2] - STEP[240]
# Generator_loss:1.0552
# L1_loss:0.2223
# Discriminator_loss:0.7217
#
# EPOCH[2] - STEP[250]
# Generator_loss:1.4732
# L1_loss:0.2410
# Discriminator_loss:0.5354
#
# EPOCH[3] - STEP[10]
# Generator_loss:1.4609
# L1_loss:0.2075
# Discriminator_loss:0.6431
#
# EPOCH[3] - STEP[20]
# Generator_loss:1.4328
# L1_loss:0.2111
# Discriminator_loss:1.1765
#
# EPOCH[3] - STEP[30]
# Generator_loss:1.4288
# L1_loss:0.2388
# Discriminator_loss:0.9815
#
# EPOCH[3] - STEP[40]
# Generator_loss:1.6664
# L1_loss:0.2054
# Discriminator_loss:0.6789
#
# EPOCH[3] - STEP[50]
# Generator_loss:2.1418
# L1_loss:0.1943
# Discriminator_loss:0.8640
#
# EPOCH[3] - STEP[60]
# Generator_loss:4.2997
# L1_loss:0.1749
# Discriminator_loss:1.9809
# EPOCH[3] - STEP[70]
# Generator_loss:2.1861
# L1_loss:0.1918
# Discriminator_loss:0.3685
#
# EPOCH[3] - STEP[80]
# Generator_loss:2.5897
# L1_loss:0.1660
# Discriminator_loss:0.5981
#
# EPOCH[3] - STEP[90]
# Generator_loss:2.9646
# L1_loss:0.1591
# Discriminator_loss:1.1003
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.6998
# L1_loss:0.1996
# Discriminator_loss:0.6182
#
# EPOCH[3] - STEP[110]
# Generator_loss:1.5585
# L1_loss:0.1979
# Discriminator_loss:1.2299
#
# EPOCH[3] - STEP[120]
# Generator_loss:1.3745
# L1_loss:0.1960
# Discriminator_loss:0.8704
#
# EPOCH[3] - STEP[130]
# Generator_loss:0.5042
# L1_loss:0.2113
# Discriminator_loss:1.1644
#
# EPOCH[3] - STEP[140]
# Generator_loss:2.0102
# L1_loss:0.1970
# Discriminator_loss:0.3530
#
# EPOCH[3] - STEP[150]
# Generator_loss:2.4953
# L1_loss:0.2107
# Discriminator_loss:1.4748
#
# EPOCH[3] - STEP[160]
# Generator_loss:3.0174
# L1_loss:0.1648
# Discriminator_loss:0.7341
#
# EPOCH[3] - STEP[170]
# Generator_loss:0.5908
# L1_loss:0.2644
# Discriminator_loss:0.9718
#
# EPOCH[3] - STEP[180]
# Generator_loss:3.3112
# L1_loss:0.1642
# Discriminator_loss:0.9894
#
# EPOCH[3] - STEP[190]
# Generator_loss:2.0531
# L1_loss:0.2348
# Discriminator_loss:0.4297
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.4049
# L1_loss:0.1953
# Discriminator_loss:0.8954
#
# EPOCH[3] - STEP[210]
# Generator_loss:1.0269
# L1_loss:0.2303
# Discriminator_loss:0.6595
#
# EPOCH[3] - STEP[220]
# Generator_loss:2.1544
# L1_loss:0.1622
# Discriminator_loss:0.7020
#
# EPOCH[3] - STEP[230]
# Generator_loss:2.2577
# L1_loss:0.2409
# Discriminator_loss:0.3491
#
# EPOCH[3] - STEP[240]
# Generator_loss:2.2644
# L1_loss:0.2025
# Discriminator_loss:0.4229
#
# EPOCH[3] - STEP[250]
# Generator_loss:2.6216
# L1_loss:0.2034
# Discriminator_loss:0.6703
#
# EPOCH[4] - STEP[10]
# Generator_loss:2.2238
# L1_loss:0.2063
# Discriminator_loss:1.3362
#
# EPOCH[4] - STEP[20]
# Generator_loss:1.3776
# L1_loss:0.1556
# Discriminator_loss:0.8380
#
# EPOCH[4] - STEP[30]
# Generator_loss:2.4112
# L1_loss:0.1671
# Discriminator_loss:0.4940
#
# EPOCH[4] - STEP[40]
# Generator_loss:0.9620
# L1_loss:0.2281
# Discriminator_loss:0.7519
#
# EPOCH[4] - STEP[50]
# Generator_loss:1.6335
# L1_loss:0.1920
# Discriminator_loss:1.0854
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.2062
# L1_loss:0.1981
# Discriminator_loss:0.6150
#
# EPOCH[4] - STEP[70]
# Generator_loss:0.9684
# L1_loss:0.2380
# Discriminator_loss:1.3862
#
# EPOCH[4] - STEP[80]
# Generator_loss:1.7598
# L1_loss:0.1723
# Discriminator_loss:0.7797
#
# EPOCH[4] - STEP[90]
# Generator_loss:3.5519
# L1_loss:0.1871
# Discriminator_loss:1.2993
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.9626
# L1_loss:0.1784
# Discriminator_loss:0.9730
#
# EPOCH[4] - STEP[110]
# Generator_loss:1.8618
# L1_loss:0.2610
# Discriminator_loss:0.5298
#
# EPOCH[4] - STEP[120]
# Generator_loss:0.8248
# L1_loss:0.1923
# Discriminator_loss:0.7745
#
# EPOCH[4] - STEP[130]
# Generator_loss:2.2699
# L1_loss:0.2136
# Discriminator_loss:0.5770
#
# EPOCH[4] - STEP[140]
# Generator_loss:0.5807
# L1_loss:0.2479
# Discriminator_loss:1.1975
#
# EPOCH[4] - STEP[150]
# Generator_loss:0.4301
# L1_loss:0.1982
# Discriminator_loss:1.5035
#
# EPOCH[4] - STEP[160]
# Generator_loss:2.2130
# L1_loss:0.1970
# Discriminator_loss:0.3886
#
# EPOCH[4] - STEP[170]
# Generator_loss:2.4922
# L1_loss:0.1757
# Discriminator_loss:0.7943
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.6649
# L1_loss:0.2177
# Discriminator_loss:0.6890
#
# EPOCH[4] - STEP[190]
# Generator_loss:1.4139
# L1_loss:0.1892
# Discriminator_loss:1.1463
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.6966
# L1_loss:0.2058
# Discriminator_loss:0.5201
#
# EPOCH[4] - STEP[210]
# Generator_loss:1.4783
# L1_loss:0.2211
# Discriminator_loss:0.5431
#
# EPOCH[4] - STEP[220]
# Generator_loss:0.8996
# L1_loss:0.2435
# Discriminator_loss:0.6972
#
# EPOCH[4] - STEP[230]
# Generator_loss:1.2401
# L1_loss:0.1960
# Discriminator_loss:0.5866
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.7723
# L1_loss:0.2074
# Discriminator_loss:1.3972
#
# EPOCH[4] - STEP[250]
# Generator_loss:1.8863
# L1_loss:0.1852
# Discriminator_loss:0.6281
#
# EPOCH[5] - STEP[10]
# Generator_loss:0.9331
# L1_loss:0.1961
# Discriminator_loss:0.9504
#
# EPOCH[5] - STEP[20]
# Generator_loss:2.2343
# L1_loss:0.1591
# Discriminator_loss:2.6586
#
# EPOCH[5] - STEP[30]
# Generator_loss:2.8406
# L1_loss:0.1989
# Discriminator_loss:0.7353
#
# EPOCH[5] - STEP[40]
# Generator_loss:2.9062
# L1_loss:0.1876
# Discriminator_loss:1.0470
#
# EPOCH[5] - STEP[50]
# Generator_loss:1.0579
# L1_loss:0.2240
# Discriminator_loss:0.5924
#
# EPOCH[5] - STEP[60]
# Generator_loss:2.1391
# L1_loss:0.2221
# Discriminator_loss:0.8335
#
# EPOCH[5] - STEP[70]
# Generator_loss:0.7559
# L1_loss:0.2221
# Discriminator_loss:0.8212
#
# EPOCH[5] - STEP[80]
# Generator_loss:1.7648
# L1_loss:0.1914
# Discriminator_loss:0.4594
#
# EPOCH[5] - STEP[90]
# Generator_loss:0.8742
# L1_loss:0.1764
# Discriminator_loss:1.0372
#
# EPOCH[5] - STEP[100]
# Generator_loss:2.7571
# L1_loss:0.1680
# Discriminator_loss:0.8062
#
# EPOCH[5] - STEP[110]
# Generator_loss:2.4017
# L1_loss:0.2641
# Discriminator_loss:0.4197
#
# EPOCH[5] - STEP[120]
# Generator_loss:1.1889
# L1_loss:0.2084
# Discriminator_loss:0.6438
# EPOCH[5] - STEP[130]
# Generator_loss:2.2451
# L1_loss:0.1694
# Discriminator_loss:0.8590
#
# EPOCH[5] - STEP[140]
# Generator_loss:1.0229
# L1_loss:0.1958
# Discriminator_loss:0.7600
#
# EPOCH[5] - STEP[150]
# Generator_loss:0.5456
# L1_loss:0.2190
# Discriminator_loss:1.0725
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.1752
# L1_loss:0.1867
# Discriminator_loss:0.5449
#
# EPOCH[5] - STEP[170]
# Generator_loss:2.1155
# L1_loss:0.2025
# Discriminator_loss:0.3468
#
# EPOCH[5] - STEP[180]
# Generator_loss:0.9025
# L1_loss:0.1707
# Discriminator_loss:0.6870
#
# EPOCH[5] - STEP[190]
# Generator_loss:1.6841
# L1_loss:0.2332
# Discriminator_loss:0.6682
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.9165
# L1_loss:0.2106
# Discriminator_loss:0.4358
#
# EPOCH[5] - STEP[210]
# Generator_loss:2.4175
# L1_loss:0.2122
# Discriminator_loss:0.7276
#
# EPOCH[5] - STEP[220]
# Generator_loss:0.8942
# L1_loss:0.2036
# Discriminator_loss:1.1473
#
# EPOCH[5] - STEP[230]
# Generator_loss:1.6371
# L1_loss:0.2649
# Discriminator_loss:0.7399
#
# EPOCH[5] - STEP[240]
# Generator_loss:1.6345
# L1_loss:0.2253
# Discriminator_loss:0.5091
#
# EPOCH[5] - STEP[250]
# Generator_loss:1.8666
# L1_loss:0.2276
# Discriminator_loss:0.3951
#
# EPOCH[6] - STEP[10]
# Generator_loss:1.5876
# L1_loss:0.1712
# Discriminator_loss:0.6155
#
# EPOCH[6] - STEP[20]
# Generator_loss:1.7308
# L1_loss:0.2163
# Discriminator_loss:0.3985
#
# EPOCH[6] - STEP[30]
# Generator_loss:1.7900
# L1_loss:0.2033
# Discriminator_loss:0.3318
#
# EPOCH[6] - STEP[40]
# Generator_loss:2.5040
# L1_loss:0.1840
# Discriminator_loss:0.8009
#
# EPOCH[6] - STEP[50]
# Generator_loss:1.0353
# L1_loss:0.2009
# Discriminator_loss:0.5946
#
# EPOCH[6] - STEP[60]
# Generator_loss:1.7165
# L1_loss:0.1936
# Discriminator_loss:0.6677
#
# EPOCH[6] - STEP[70]
# Generator_loss:2.1012
# L1_loss:0.1843
# Discriminator_loss:1.0589
#
# EPOCH[6] - STEP[80]
# Generator_loss:2.4006
# L1_loss:0.1873
# Discriminator_loss:0.2444
#
# EPOCH[6] - STEP[90]
# Generator_loss:2.5269
# L1_loss:0.1914
# Discriminator_loss:0.8419
#
# EPOCH[6] - STEP[100]
# Generator_loss:2.3855
# L1_loss:0.1817
# Discriminator_loss:1.4881
#
# EPOCH[6] - STEP[110]
# Generator_loss:1.1905
# L1_loss:0.1637
# Discriminator_loss:0.5686
#
# EPOCH[6] - STEP[120]
# Generator_loss:1.2325
# L1_loss:0.1886
# Discriminator_loss:0.9546
#
# EPOCH[6] - STEP[130]
# Generator_loss:1.9822
# L1_loss:0.1958
# Discriminator_loss:0.5186
#
# EPOCH[6] - STEP[140]
# Generator_loss:0.7333
# L1_loss:0.1873
# Discriminator_loss:1.0157
#
# EPOCH[6] - STEP[150]
# Generator_loss:0.7682
# L1_loss:0.1877
# Discriminator_loss:0.8175
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.0860
# L1_loss:0.1834
# Discriminator_loss:0.6539
#
# EPOCH[6] - STEP[170]
# Generator_loss:0.9757
# L1_loss:0.1926
# Discriminator_loss:1.0147
#
# EPOCH[6] - STEP[180]
# Generator_loss:1.6010
# L1_loss:0.2179
# Discriminator_loss:1.0170
#
# EPOCH[6] - STEP[190]
# Generator_loss:2.0482
# L1_loss:0.2063
# Discriminator_loss:0.4808
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.9990
# L1_loss:0.1823
# Discriminator_loss:0.8228
#
# EPOCH[6] - STEP[210]
# Generator_loss:1.0492
# L1_loss:0.2114
# Discriminator_loss:0.9334
#
# EPOCH[6] - STEP[220]
# Generator_loss:0.3408
# L1_loss:0.1901
# Discriminator_loss:1.5598
#
# EPOCH[6] - STEP[230]
# Generator_loss:1.7234
# L1_loss:0.2278
# Discriminator_loss:0.3657
#
# EPOCH[6] - STEP[240]
# Generator_loss:0.7091
# L1_loss:0.1686
# Discriminator_loss:0.8973
#
# EPOCH[6] - STEP[250]
# Generator_loss:0.4004
# L1_loss:0.1847
# Discriminator_loss:1.4294
#
# EPOCH[7] - STEP[10]
# Generator_loss:2.5297
# L1_loss:0.1857
# Discriminator_loss:0.1844
#
# EPOCH[7] - STEP[20]
# Generator_loss:3.1291
# L1_loss:0.2117
# Discriminator_loss:0.9902
#
# EPOCH[7] - STEP[30]
# Generator_loss:3.8768
# L1_loss:0.1760
# Discriminator_loss:3.1170
#
# EPOCH[7] - STEP[40]
# Generator_loss:3.0002
# L1_loss:0.2291
# Discriminator_loss:0.3459
#
# EPOCH[7] - STEP[50]
# Generator_loss:2.4264
# L1_loss:0.1805
# Discriminator_loss:0.4669
#
# EPOCH[7] - STEP[60]
# Generator_loss:2.5182
# L1_loss:0.2039
# Discriminator_loss:0.6511
#
# EPOCH[7] - STEP[70]
# Generator_loss:1.3836
# L1_loss:0.2051
# Discriminator_loss:0.5669
#
# EPOCH[7] - STEP[80]
# Generator_loss:0.8387
# L1_loss:0.1670
# Discriminator_loss:0.8306
#
# EPOCH[7] - STEP[90]
# Generator_loss:1.8764
# L1_loss:0.1782
# Discriminator_loss:0.6846
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.1937
# L1_loss:0.1744
# Discriminator_loss:0.7823
#
# EPOCH[7] - STEP[110]
# Generator_loss:2.1494
# L1_loss:0.2036
# Discriminator_loss:1.0726
#
# EPOCH[7] - STEP[120]
# Generator_loss:1.4139
# L1_loss:0.2023
# Discriminator_loss:0.4594
#
# EPOCH[7] - STEP[130]
# Generator_loss:1.8139
# L1_loss:0.1879
# Discriminator_loss:0.2490
#
# EPOCH[7] - STEP[140]
# Generator_loss:1.3753
# L1_loss:0.1660
# Discriminator_loss:0.5690
#
# EPOCH[7] - STEP[150]
# Generator_loss:0.2757
# L1_loss:0.1874
# Discriminator_loss:1.7060
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.6501
# L1_loss:0.1932
# Discriminator_loss:0.4668
#
# EPOCH[7] - STEP[170]
# Generator_loss:0.3199
# L1_loss:0.1998
# Discriminator_loss:1.8256
#
# EPOCH[7] - STEP[180]
# Generator_loss:1.5974
# L1_loss:0.1803
# Discriminator_loss:0.3694
# EPOCH[7] - STEP[190]
# Generator_loss:1.4558
# L1_loss:0.1874
# Discriminator_loss:0.7674
#
# EPOCH[7] - STEP[200]
# Generator_loss:0.6214
# L1_loss:0.1827
# Discriminator_loss:1.1896
#
# EPOCH[7] - STEP[210]
# Generator_loss:1.5655
# L1_loss:0.1970
# Discriminator_loss:0.5835
#
# EPOCH[7] - STEP[220]
# Generator_loss:3.3115
# L1_loss:0.2044
# Discriminator_loss:0.3981
#
# EPOCH[7] - STEP[230]
# Generator_loss:2.5191
# L1_loss:0.2264
# Discriminator_loss:0.7361
#
# EPOCH[7] - STEP[240]
# Generator_loss:0.4231
# L1_loss:0.1961
# Discriminator_loss:1.5286
#
# EPOCH[7] - STEP[250]
# Generator_loss:1.5553
# L1_loss:0.1705
# Discriminator_loss:0.7611
#
# EPOCH[8] - STEP[10]
# Generator_loss:1.2849
# L1_loss:0.1896
# Discriminator_loss:0.6193
#
# EPOCH[8] - STEP[20]
# Generator_loss:1.3094
# L1_loss:0.1861
# Discriminator_loss:0.7824
#
# EPOCH[8] - STEP[30]
# Generator_loss:1.5149
# L1_loss:0.1918
# Discriminator_loss:0.4904
#
# EPOCH[8] - STEP[40]
# Generator_loss:1.9307
# L1_loss:0.2083
# Discriminator_loss:1.1640
#
# EPOCH[8] - STEP[50]
# Generator_loss:0.6221
# L1_loss:0.1988
# Discriminator_loss:0.9065
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.9867
# L1_loss:0.1653
# Discriminator_loss:0.7835
#
# EPOCH[8] - STEP[70]
# Generator_loss:2.1311
# L1_loss:0.1707
# Discriminator_loss:0.6177
#
# EPOCH[8] - STEP[80]
# Generator_loss:0.9646
# L1_loss:0.2052
# Discriminator_loss:0.9572
#
# EPOCH[8] - STEP[90]
# Generator_loss:0.8044
# L1_loss:0.2086
# Discriminator_loss:1.1227
#
# EPOCH[8] - STEP[100]
# Generator_loss:2.9227
# L1_loss:0.1591
# Discriminator_loss:0.9802
#
# EPOCH[8] - STEP[110]
# Generator_loss:2.2454
# L1_loss:0.1769
# Discriminator_loss:0.2747
#
# EPOCH[8] - STEP[120]
# Generator_loss:1.3209
# L1_loss:0.2091
# Discriminator_loss:0.6834
#
# EPOCH[8] - STEP[130]
# Generator_loss:0.7832
# L1_loss:0.2115
# Discriminator_loss:0.7451
#
# EPOCH[8] - STEP[140]
# Generator_loss:2.9481
# L1_loss:0.2090
# Discriminator_loss:0.4083
#
# EPOCH[8] - STEP[150]
# Generator_loss:1.6978
# L1_loss:0.1917
# Discriminator_loss:0.5868
#
# EPOCH[8] - STEP[160]
# Generator_loss:0.7882
# L1_loss:0.1536
# Discriminator_loss:0.9349
#
# EPOCH[8] - STEP[170]
# Generator_loss:1.2808
# L1_loss:0.1900
# Discriminator_loss:0.6331
#
# EPOCH[8] - STEP[180]
# Generator_loss:2.1619
# L1_loss:0.1737
# Discriminator_loss:0.7693
#
# EPOCH[8] - STEP[190]
# Generator_loss:1.8705
# L1_loss:0.1900
# Discriminator_loss:0.9567
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.6498
# L1_loss:0.1904
# Discriminator_loss:0.5362
#
# EPOCH[8] - STEP[210]
# Generator_loss:2.3384
# L1_loss:0.1885
# Discriminator_loss:0.4354
#
# EPOCH[8] - STEP[220]
# Generator_loss:0.6891
# L1_loss:0.1663
# Discriminator_loss:1.1004
#
# EPOCH[8] - STEP[230]
# Generator_loss:0.5768
# L1_loss:0.2183
# Discriminator_loss:1.0315
#
# EPOCH[8] - STEP[240]
# Generator_loss:1.6963
# L1_loss:0.1848
# Discriminator_loss:0.4986
#
# EPOCH[8] - STEP[250]
# Generator_loss:2.8512
# L1_loss:0.1962
# Discriminator_loss:0.5387
#
# EPOCH[9] - STEP[10]
# Generator_loss:0.1714
# L1_loss:0.1603
# Discriminator_loss:2.6378
#
# EPOCH[9] - STEP[20]
# Generator_loss:1.9015
# L1_loss:0.1611
# Discriminator_loss:0.7521
#
# EPOCH[9] - STEP[30]
# Generator_loss:1.7512
# L1_loss:0.1595
# Discriminator_loss:0.4074
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.2886
# L1_loss:0.1788
# Discriminator_loss:0.5814
#
# EPOCH[9] - STEP[50]
# Generator_loss:2.9435
# L1_loss:0.1578
# Discriminator_loss:0.6538
#
# EPOCH[9] - STEP[60]
# Generator_loss:2.5249
# L1_loss:0.1829
# Discriminator_loss:0.2159
#
# EPOCH[9] - STEP[70]
# Generator_loss:0.8773
# L1_loss:0.1770
# Discriminator_loss:0.7571
#
# EPOCH[9] - STEP[80]
# Generator_loss:1.4020
# L1_loss:0.2010
# Discriminator_loss:0.6990
#
# EPOCH[9] - STEP[90]
# Generator_loss:0.4605
# L1_loss:0.1904
# Discriminator_loss:1.4345
#
# EPOCH[9] - STEP[100]
# Generator_loss:2.2580
# L1_loss:0.1757
# Discriminator_loss:0.6049
#
# EPOCH[9] - STEP[110]
# Generator_loss:0.9809
# L1_loss:0.2260
# Discriminator_loss:0.6994
#
# EPOCH[9] - STEP[120]
# Generator_loss:0.9207
# L1_loss:0.1675
# Discriminator_loss:1.2423
#
# EPOCH[9] - STEP[130]
# Generator_loss:0.4697
# L1_loss:0.1636
# Discriminator_loss:1.3726
#
# EPOCH[9] - STEP[140]
# Generator_loss:2.0416
# L1_loss:0.2078
# Discriminator_loss:0.2534
#
# EPOCH[9] - STEP[150]
# Generator_loss:2.5640
# L1_loss:0.1390
# Discriminator_loss:1.3036
#
# EPOCH[9] - STEP[160]
# Generator_loss:0.6590
# L1_loss:0.1894
# Discriminator_loss:1.0424
#
# EPOCH[9] - STEP[170]
# Generator_loss:1.0041
# L1_loss:0.2151
# Discriminator_loss:0.6071
#
# EPOCH[9] - STEP[180]
# Generator_loss:2.0397
# L1_loss:0.1824
# Discriminator_loss:0.9832
#
# EPOCH[9] - STEP[190]
# Generator_loss:3.5550
# L1_loss:0.1748
# Discriminator_loss:1.4239
#
# EPOCH[9] - STEP[200]
# Generator_loss:3.0581
# L1_loss:0.1718
# Discriminator_loss:1.4649
#
# EPOCH[9] - STEP[210]
# Generator_loss:2.0289
# L1_loss:0.1628
# Discriminator_loss:0.3290
#
# EPOCH[9] - STEP[220]
# Generator_loss:1.5243
# L1_loss:0.1558
# Discriminator_loss:0.7798
#
# EPOCH[9] - STEP[230]
# Generator_loss:4.1610
# L1_loss:0.1610
# Discriminator_loss:1.2965
#
# EPOCH[9] - STEP[240]
# Generator_loss:1.4137
# L1_loss:0.1700
# Discriminator_loss:0.4750
# EPOCH[9] - STEP[250]
# Generator_loss:0.2761
# L1_loss:0.2087
# Discriminator_loss:1.6359
#
# EPOCH[10] - STEP[10]
# Generator_loss:0.7858
# L1_loss:0.1470
# Discriminator_loss:0.7840
#
# EPOCH[10] - STEP[20]
# Generator_loss:1.6145
# L1_loss:0.1575
# Discriminator_loss:0.5836
#
# EPOCH[10] - STEP[30]
# Generator_loss:0.9748
# L1_loss:0.1501
# Discriminator_loss:1.4222
#
# EPOCH[10] - STEP[40]
# Generator_loss:2.0787
# L1_loss:0.1974
# Discriminator_loss:0.2663
#
# EPOCH[10] - STEP[50]
# Generator_loss:1.2393
# L1_loss:0.1655
# Discriminator_loss:0.8769
#
# EPOCH[10] - STEP[60]
# Generator_loss:0.8273
# L1_loss:0.1505
# Discriminator_loss:1.0788
#
# EPOCH[10] - STEP[70]
# Generator_loss:1.2226
# L1_loss:0.1768
# Discriminator_loss:0.5490
#
# EPOCH[10] - STEP[80]
# Generator_loss:2.2402
# L1_loss:0.1540
# Discriminator_loss:0.8238
#
# EPOCH[10] - STEP[90]
# Generator_loss:0.7254
# L1_loss:0.1818
# Discriminator_loss:1.5617
#
# EPOCH[10] - STEP[100]
# Generator_loss:2.7689
# L1_loss:0.1916
# Discriminator_loss:0.1917
#
# EPOCH[10] - STEP[110]
# Generator_loss:3.0369
# L1_loss:0.1495
# Discriminator_loss:1.5742
#
# EPOCH[10] - STEP[120]
# Generator_loss:2.2495
# L1_loss:0.1887
# Discriminator_loss:0.3195
#
# EPOCH[10] - STEP[130]
# Generator_loss:1.3775
# L1_loss:0.2316
# Discriminator_loss:0.4235
#
# EPOCH[10] - STEP[140]
# Generator_loss:2.7954
# L1_loss:0.1831
# Discriminator_loss:0.5165
#
# EPOCH[10] - STEP[150]
# Generator_loss:2.2664
# L1_loss:0.1774
# Discriminator_loss:0.2682
#
# EPOCH[10] - STEP[160]
# Generator_loss:2.4974
# L1_loss:0.1625
# Discriminator_loss:1.5354
#
# EPOCH[10] - STEP[170]
# Generator_loss:0.8742
# L1_loss:0.2875
# Discriminator_loss:0.7271
#
# EPOCH[10] - STEP[180]
# Generator_loss:1.2646
# L1_loss:0.1766
# Discriminator_loss:0.8634
#
# EPOCH[10] - STEP[190]
# Generator_loss:0.3080
# L1_loss:0.2157
# Discriminator_loss:1.5259
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.7610
# L1_loss:0.1802
# Discriminator_loss:0.3911
#
# EPOCH[10] - STEP[210]
# Generator_loss:2.0165
# L1_loss:0.1520
# Discriminator_loss:0.5397
#
# EPOCH[10] - STEP[220]
# Generator_loss:1.1797
# L1_loss:0.1863
# Discriminator_loss:0.8311
#
# EPOCH[10] - STEP[230]
# Generator_loss:1.0363
# L1_loss:0.1941
# Discriminator_loss:0.6104
#
# EPOCH[10] - STEP[240]
# Generator_loss:3.1454
# L1_loss:0.2188
# Discriminator_loss:0.3685
#
# EPOCH[10] - STEP[250]
# Generator_loss:1.9769
# L1_loss:0.1596
# Discriminator_loss:1.0629

# %%
# 테스트
test_ind = 1
data_path2 = os.getenv('HOME')+'/aiffel/Segmentation_map/data/cityscapes/val/'
f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# 생각보다 라벨링이 꽤 괜찮게 칠해진 것을 확인할 수 있다.

# %% [markdown]
# # 마무리

# %% [markdown]
# 기존에 진행했던 포켓몬 실습과 큰 차이는 없었다.<Br>
# Segmentation map으로 도로 이미지를 만들었는데, Pix2Pix를 활용한 라벨링에 조금 익숙해진 것 같다.
