# %%
import numpy as np
import pandas as pd

# %%
# 엑셀 파일을 불러오겠습니다.  
# 현재 쥬피터노트북 파일 위치 기준으로(./) data 폴더 내의 babyNamesUS.csv 파일입니다. 
file = './lotto.xlsx'
raw = pd.read_excel(file)

# %%
raw.head()
# Out:
#   회차별 추첨결과 Unnamed: 1  Unnamed: 2 Unnamed: 3      Unnamed: 4 Unnamed: 5  \
# 0       년도         회차         추첨일         1등             NaN         2등
# 1      NaN        NaN         NaN       당첨자수            당첨금액       당첨자수
# 2     2022       1003  2022.02.19         14  1,811,116,822원         66
# 3      NaN       1002  2022.02.12          8  3,088,449,563원         85
# 4      NaN       1001  2022.02.05         12  2,077,279,594원         66
#
#     Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0          NaN         3등         NaN         4등         NaN          5등
# 1         당첨금액       당첨자수        당첨금액       당첨자수        당첨금액        당첨자수
# 2  64,029,383원       2649  1,595,297원     133896     50,000원     2247475
# 3  48,446,268원       3193  1,289,676원     155418     50,000원     2436676
# 4  62,947,867원       2761  1,504,730원     140255     50,000원     2346904
#
#   Unnamed: 12 Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  \
# ...
