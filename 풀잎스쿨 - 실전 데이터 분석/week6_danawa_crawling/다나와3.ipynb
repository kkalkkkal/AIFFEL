# %%
import pandas as pd
danawa_data = pd.read_excel('실습2.xlsx', thousands =',')
danawa_data.head()
# Out:
#        카테고리    회사명                  제품      가격  사용시간    흡입력
# 0  핸디/스틱청소기   삼성전자    제트 VS20T9218QDCC  466520    60  200.0
# 1  핸디/스틱청소기   아이코넬     차량용 청소기 ICL-V01  466520    60  200.0
# 2  핸디/스틱청소기  케이디와이  휴대용 미니청소기 KPV-3525  466520    60  200.0
# 3  핸디/스틱청소기   신일전자   롤링스턴 SDC-CO3074WK  466520    60  200.0
# 4  핸디/스틱청소기   LG전자   코드제로 A9S AS9200BA  466520    60  200.0

# %%
top_list = danawa_data.sort_values(["흡입력"], ascending = False)
top_list.head()
# Out:
#          카테고리    회사명                    제품      가격  사용시간    흡입력
# 199  핸디/스틱청소기    차량용  애니스 초강력 핸디 청소기 JB14P  198000    50  300.0
# 179  핸디/스틱청소기     보쉬           GAS10.8V-LI  198000    50  300.0
# 177  핸디/스틱청소기     보랄        텀블러 무선 차량용 청소기  198000    50  300.0
# 176  핸디/스틱청소기     다온                파워풀 K7  198000    50  300.0
# 175  핸디/스틱청소기  에이스전자          AVG-LC9600BT  198000    50  300.0

# %%
top_list = danawa_data.sort_values(["사용시간"], ascending = False)
top_list.head()
# Out:
#         카테고리     회사명                             제품      가격  사용시간    흡입력
# 0   핸디/스틱청소기    삼성전자               제트 VS20T9218QDCC  466520    60  200.0
# 41  핸디/스틱청소기    LG전자           코드제로 ThinQ A9S A9700  837910    60  220.0
# 59  핸디/스틱청소기     샤오미  CLEANFLY 차량용 무선 청소기 H1 (해외구매)  837910    60  220.0
# 58  핸디/스틱청소기     리하스                             S3  837910    60  220.0
# 57  핸디/스틱청소기  일렉트로룩스           에르고라피도 베드프로 ZB3323BO  837910    60  220.0

# %%
top_list = danawa_data.sort_values(["사용시간","흡입력"], ascending = False)
top_list.head()
# Out:
#         카테고리    회사명                    제품      가격  사용시간    흡입력
# 40  핸디/스틱청소기   삼성전자    비스포크 제트 VS20B957D4  837910    60  220.0
# 41  핸디/스틱청소기   LG전자  코드제로 ThinQ A9S A9700  837910    60  220.0
# 42  핸디/스틱청소기    툴앤툴            네오스틱 T400W  837910    60  220.0
# 43  핸디/스틱청소기  알로코리아       차량용 무선 청소기 AVC1  837910    60  220.0
# 44  핸디/스틱청소기  DIBEA       차이슨 ALLNEW22000  837910    60  220.0

# %%
price_mean_value = danawa_data['가격'].mean()
suction_mean_value = danawa_data['흡입력'].mean()
use_time_mean_value = danawa_data['사용시간'].mean()
print("가격 평균값", price_mean_value)
print("흡입력 평균값", suction_mean_value)
print("사용시간 평균값", use_time_mean_value)
# Out:
# 가격 평균값 315841.6666666667
# 흡입력 평균값 240.0
# 사용시간 평균값 43.333333333333336

# %%
condition_data = danawa_data [
    (danawa_data['가격'] <= price_mean_value) & 
    (danawa_data['흡입력'] >= suction_mean_value) & 
    (danawa_data['사용시간'] >= use_time_mean_value)]
condition_data
# Out:
#          카테고리      회사명                         제품      가격  사용시간    흡입력
# 160  핸디/스틱청소기      아이닉                    NEW i20  198000    50  300.0
# 161  핸디/스틱청소기   일렉트로룩스         WELL Q7 WQ71-2BSWF  198000    50  300.0
# 162  핸디/스틱청소기     삼성전자         비스포크 제트 VS20B957D5  198000    50  300.0
# 163  핸디/스틱청소기      마미봇                        클로모  198000    50  300.0
# 164  핸디/스틱청소기      마이딘         차량용 무선 청소기 MCV6000  198000    50  300.0
# 165  핸디/스틱청소기     유니맥스            차량용 무선 BLDC 청소기  198000    50  300.0
# 166  핸디/스틱청소기      라우쉬         (RAUSCH) LSDS-7000  198000    50  300.0
# 167  핸디/스틱청소기       지웰                 벤투스 아쿠아 프로  198000    50  300.0
# 168  핸디/스틱청소기   일렉트로룩스             퓨어 Q9 PQ91-3OB  198000    50  300.0
# 169  핸디/스틱청소기   일렉트로룩스          WELL Q7 WQ71-2OIB  198000    50  300.0
# 170  핸디/스틱청소기       기펠                     ZET-10  198000    50  300.0
# 171  핸디/스틱청소기    DIBEA                    M500 퀀텀  198000    50  300.0
# 172  핸디/스틱청소기      홈마블                       H100  198000    50  300.0
# 173  핸디/스틱청소기    한빛시스템                    HV-5088  198000    50  300.0
# 174  핸디/스틱청소기    한빛시스템                    HV-5099  198000    50  300.0
# 175  핸디/스틱청소기    에이스전자               AVG-LC9600BT  198000    50  300.0
# 176  핸디/스틱청소기       다온                     파워풀 K7  198000    50  300.0
# 177  핸디/스틱청소기       보랄             텀블러 무선 차량용 청소기  198000    50  300.0
# 178  핸디/스틱청소기      다이슨                   V11 컴플리트  198000    50  300.0
# 179  핸디/스틱청소기       보쉬                GAS10.8V-LI  198000    50  300.0
# 180  핸디/스틱청소기      샤오미                    드리미 T20  198000    50  300.0
# 181  핸디/스틱청소기     신일전자                 SVC-S500YT  198000    50  300.0
# 182  핸디/스틱청소기    무궁화전자               바로바로 MC-B601  198000    50  300.0
# 183  핸디/스틱청소기      마끼다                    DCL180Z  198000    50  300.0
# 184  핸디/스틱청소기     삼성전자             제트 VS20T92K3QD  198000    50  300.0
# 185  핸디/스틱청소기   일렉트로룩스         WELL Q8 WQ81-3PSGF  198000    50  300.0
# 186  핸디/스틱청소기       테팔          에어포스 라이트 TY6545KL  198000    50  300.0
# 187  핸디/스틱청소기    베이스어스  차량용 청소기 A3 + 전용 필터 (해외구매)  198000    50  300.0
# 188  핸디/스틱청소기      다이슨             V11 220AW 컴플리트  198000    50  300.0
# 189  핸디/스틱청소기   일렉트로룩스          얼티밋홈 900 EFP91825  198000    50  300.0
# 190  핸디/스틱청소기    인터하우스       차량용 무선청소기 GVC-6000MG  198000    50  300.0
# 191  핸디/스틱청소기    DIBEA                        D18  198000    50  300.0
# 192  핸디/스틱청소기     삼성전자         비스포크 제트 VS20A957F3  198000    50  300.0
# 193  핸디/스틱청소기      샤오미                     미홀 K11  198000    50  300.0
# 194  핸디/스틱청소기      샤오미                    로이드미 S2  198000    50  300.0
# 195  핸디/스틱청소기       빌톤                 MBT-C1000W  198000    50  300.0
# 196  핸디/스틱청소기      다이슨                     V8 플러피  198000    50  300.0
# 197  핸디/스틱청소기  스위스밀리터리            에어슬림 SMA-BV2200  198000    50  300.0
# 198  핸디/스틱청소기     LG전자    코드제로 ThinQ A9S AT9401IB  198000    50  300.0
# 199  핸디/스틱청소기      차량용       애니스 초강력 핸디 청소기 JB14P  198000    50  300.0

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import seaborn as sns
import platform 

font_path = ''
if platform.system() == 'Windows': 
    font_path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname = font_path).get_name()
    rc('font', family = font_name)
elif platform.system() == 'Darwin':
    font_path = '/Users/$USER/Library/Fonts/AppleGothic.ttf'
    rc('font', family = 'AppleGothic')
else: 
    print('Check your OS system')
    
# %matplotlib inline

# %%
chart_data = danawa_data.dropna(axis = 0)
len(chart_data)
# Out:
# 120

# %%
suction_max_value = chart_data['흡입력'].max()
suction_mean_value = chart_data['흡입력'].mean()
use_time_max_value = chart_data['사용시간'].max()
use_time_mean_value = chart_data['사용시간'].mean()

# %%
plt.figure(figsize=(20, 10))
plt.title("무선 핸디/스틱청소기 차트")
sns.scatterplot(x = '흡입력', y = '사용시간', size = '가격', hue = chart_data['회사명'], 
             data = chart_data, sizes = (10, 1000), legend = False)
plt.plot([0, suction_max_value], 
          [use_time_mean_value, use_time_mean_value], 
          'r--', 
          lw = 1 )
plt.plot([suction_mean_value, suction_mean_value], 
          [0, use_time_max_value], 
          'r--', 
          lw = 1 )
plt.show()

# %%
chart_data_selected = chart_data[:20]
len(chart_data_selected)
# Out:
# 20

# %%
suction_max_value = chart_data_selected['흡입력'].max()
suction_mean_value = chart_data_selected['흡입력'].mean()
use_time_max_value = chart_data_selected['사용시간'].max()
use_time_mean_value = chart_data_selected['사용시간'].mean()
plt.figure(figsize=(20, 10))
plt.title("무선 핸디/스틱청소기 TOP 20")
sns.scatterplot(x = '흡입력', 
                  y = '사용시간', 
                  size = '가격', 
                  hue = chart_data_selected['회사명'], 
                  data = chart_data_selected, sizes = (100, 2000),
                  legend = False)
plt.plot([60, suction_max_value], 
          [use_time_mean_value, use_time_mean_value], 
          'r--', 
          lw = 1 )
plt.plot([suction_mean_value, suction_mean_value], 
          [20, use_time_max_value], 
          'r--', 
          lw = 1 )
for index, row in chart_data_selected.iterrows():
    x = row['흡입력']
    y = row['사용시간']
    s = row['제품'].split(' ')[0]
    plt.text(x, y, s, size=20)
plt.show()
