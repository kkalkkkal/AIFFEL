# %% [markdown]
# # 환경 설정
#
# 1. python : 3.9.7
# 2. opencv-python : 4.5.5.62
# 3. dlib : 19.22.1

# %%
# !python --version
# !pip list |findstr opencv
# Out:
# Python 3.9.7
# opencv-python       4.5.5.62

# %%
import sys
sys.version
# Out:
# '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]'

# %%
# !pip install opencv-python
# !pip install opencv-contrib-python==4.5.2.52 --user
# !pip install opencv-python-headless==4.5.2.52 --user
# Out:
# Requirement already satisfied: opencv-python in c:\users\user\.conda\envs\python39\lib\site-packages (4.5.5.62)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\.conda\envs\python39\lib\site-packages (from opencv-python) (1.22.1)

# %%
# !pip install numpy
# !pip install cmake
# !pip install dlib
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2
# Collecting numpy
#   Downloading numpy-1.22.1-cp39-cp39-win_amd64.whl (14.7 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.22.1
# Collecting cmake
#   Using cached cmake-3.22.1-py2.py3-none-win_amd64.whl (38.1 MB)
# Installing collected packages: cmake
# Successfully installed cmake-3.22.1
# Collecting dlib
#   Using cached dlib-19.22.1-cp39-cp39-win_amd64.whl
# Installing collected packages: dlib
# Successfully installed dlib-19.22.1

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp39-cp39-win_amd64.whl (7.2 MB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.28.5-py3-none-any.whl (890 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.2-cp39-cp39-win_amd64.whl (52 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.0.0-cp39-cp39-win_amd64.whl (3.2 MB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\.conda\envs\python39\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\.conda\envs\python39\lib\site-packages (from matplotlib) (3.0.4)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\.conda\envs\python39\lib\site-packages (from matplotlib) (1.22.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\.conda\envs\python39\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\.conda\envs\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.28.5 kiwisolver-1.3.2 matplotlib-3.5.1 pillow-9.0.0

# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import dlib

# %% [markdown]
# # Step1. 고양이 수염 이미지 다운로드하기

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in c:\users\user\.conda\envs\python39\lib\site-packages (3.2)

# %% [markdown]
# 오른쪽 url에서 고양이 수염 이미지 다운로드 : "https://cdn-icons-png.flaticon.com/512/24/24674.png"
# 내 얼굴 사진은 my_face.jpg, my_face2.jpg로 저장함.

# %% [markdown]
# # Step 2. 얼굴 검출 & 랜드마크 검출 하기

# %%
# 내 얼굴 사진 확인하기 
my_image_path = './my_face2.jpg'
img_bgr = cv2.imread(my_image_path)    # OpenCV로 이미지를 불러옵니다
img_show = img_bgr.copy()      # 출력용 이미지를 따로 보관합니다

#rgb로 전황
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
#얼굴 검출하기 
detector_hog = dlib.get_frontal_face_detector()
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
dlib_rects = detector_hog(img_rgb, 1)   # (image, num of image pyramid)

# %%
print(dlib_rects)   

for dlib_rect in dlib_rects:
    l = dlib_rect.left()
    t = dlib_rect.top()
    r = dlib_rect.right()
    b = dlib_rect.bottom()

    cv2.rectangle(img_show, (l,t), (r,b), (0,255,0), 2, lineType=cv2.LINE_AA)

img_show_rgb =  cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)
plt.imshow(img_show_rgb)
plt.show()
# Out:
# rectangles[[(171, 542) (726, 1096)]]

# %% [markdown]
# # 랜드마크 검출하기
#
# "http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2" 에서 랜트마클 모델 다운로드

# %%
model_path = "./shape_predictor_68_face_landmarks.dat"
landmark_predictor = dlib.shape_predictor(model_path)

# %%
list_landmarks = []

# 얼굴 영역 박스 마다 face landmark를 찾아냅니다
for dlib_rect in dlib_rects:
    points = landmark_predictor(img_rgb, dlib_rect)
    # face landmark 좌표를 저장해둡니다
    list_points = list(map(lambda p: (p.x, p.y), points.parts()))
    list_landmarks.append(list_points)

print(len(list_landmarks[0]))
# Out:
# 68

# %%
for landmark in list_landmarks:
    for point in landmark:
        cv2.circle(img_show, point, 2, (0, 255, 255), -1)

img_show_rgb = cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)
plt.imshow(img_show_rgb)
plt.show()

# %% [markdown]
# # Step 3 스티커 적용 위치 확인하기

# %%
# 스티커의 모양은 고양이 수염인데 아래와 같다. 
my_image_path2 = './cat-whiskers.png'
img_bgr2 = cv2.imread(my_image_path2)    # OpenCV로 이미지를 불러옵니다
img_show = img_bgr2.copy()      # 출력용 이미지를 따로 보관합니다
img_h, img_w, img_c = img_bgr2.shape
print(img_h, img_w, img_c)
plt.imshow(img_show)
plt.show()
# Out:
# 512 512 3

# %%
#rgb로 전황
img_rgb2 = cv2.cvtColor(img_bgr2, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb2)
plt.show()

# %% [markdown]
# 이를 화면에 적용시키기 위해선 고양이 코의 위치를 사진 속 하단 코(콧구멍쪽)에 위치 시켜야한다.
#
# x은 이미지의 중점이지만, y값은 이미지 크지의 절반 만큼 늘리면 잘 위치될 것으로 보인다.
# 코에 위치 시키기 위해선 이미지 최하단 좌표 y와 코의 위치를 일치 시켜야하기 때문이다.
#
# 스티커의 크기는 얼굴 너비와 일치시키면 될 것으로 보인다.

# %%
# 좌표 확인 

for dlib_rect, landmark in zip(dlib_rects, list_landmarks):
    print (landmark[8]) # 코 하단의 index는 33 입니다
    x = landmark[33][0]
    y = landmark[33][1] + img_h//2
    w = h = dlib_rect.width()
    print ('(x,y) : (%d,%d)'%(x,y))
    print ('(w,h) : (%d,%d)'%(w,h))
# Out:
# (432, 1092)
# (x,y) : (428,1085)
# (w,h) : (463,463)

# %%
sticker_path = './cat-whiskers.png'
img_sticker = cv2.imread(sticker_path) # 스티커 이미지를 불러옵니다
img_sticker = cv2.resize(img_sticker, (w,h))
print (img_sticker.shape)
# Out:
# (463, 463, 3)

# %%
refined_x = x - w // 2
refined_y = y - h
print ('(x,y) : (%d,%d)'%(refined_x, refined_y))

if refined_x < 0: 
    img_sticker = img_sticker[:, -refined_x:]
    refined_x = 0
if refined_y < 0:
    img_sticker = img_sticker[-refined_y:, :]
    refined_y = 0

print ('(x,y) : (%d,%d)'%(refined_x, refined_y))
# Out:
# (x,y) : (197,622)
# (x,y) : (197,622)

# %% [markdown]
# # Step 4 스티커 적용하기

# %%
my_image_path = './my_face2.jpg'
img_bgr = cv2.imread(my_image_path)    # OpenCV로 이미지를 불러옵니다
img_show = img_bgr.copy()      # 출력용 이미지를 따로 보관합니다
plt.imshow(cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB))
plt.show()

# %%
sticker_area = img_bgr[refined_y:refined_y +img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
img_bgr[refined_y:refined_y +img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
    np.where(img_sticker==255,sticker_area,img_sticker).astype(np.uint8)
plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# 보다시피 코에 이쁘게 잘 위치되었다.

# %% [markdown]
# # Step 5. 문제점 찾아보기

# %% [markdown]
# 다른 사진 my_face3.jpg를 준비하였다.
# 해당 사진은 측면으로 고개를 꺾은 사진이다.

# %%
my_image_path2 = './my_face3.jpg'
img_bgr2 = cv2.imread(my_image_path2)    # OpenCV로 이미지를 불러옵니다
img_show3 = img_bgr2.copy()      # 출력용 이미지를 따로 보관합니다
plt.imshow(cv2.cvtColor(img_show3, cv2.COLOR_BGR2RGB))
plt.show()

# %%
#얼굴 검출하기 
detector_hog = dlib.get_frontal_face_detector()
img_rgb2 = cv2.cvtColor(img_bgr2, cv2.COLOR_BGR2RGB)
dlib_rects2 = detector_hog(img_rgb2, 1)   # (image, num of image pyramid)

print(dlib_rects2)   

for dlib_rect in dlib_rects2:
    l = dlib_rect.left()
    t = dlib_rect.top()
    r = dlib_rect.right()
    b = dlib_rect.bottom()

    cv2.rectangle(img_show3, (l,t), (r,b), (0,255,0), 2, lineType=cv2.LINE_AA)

img_show_rgb2 =  cv2.cvtColor(img_show3, cv2.COLOR_BGR2RGB)
plt.imshow(img_show_rgb2)
plt.show()
# Out:
# rectangles[[(245, 502) (707, 965)]]

# %%
list_landmarks2 = []

# 얼굴 영역 박스 마다 face landmark를 찾아냅니다
for dlib_rect in dlib_rects2:
    points = landmark_predictor(img_rgb2, dlib_rect)
    # face landmark 좌표를 저장해둡니다
    list_points = list(map(lambda p: (p.x, p.y), points.parts()))
    list_landmarks2.append(list_points)

print(len(list_landmarks2[0]))
# Out:
# 68

# %%
for dlib_rect, landmark in zip(dlib_rects2, list_landmarks2):
    print (landmark[8]) # 코 하단의 index는 33 입니다
    x = landmark[33][0]
    y = landmark[33][1] + img_h//2
    w = h = dlib_rect.width()
    print ('(x,y) : (%d,%d)'%(x,y))
    print ('(w,h) : (%d,%d)'%(w,h))
# Out:
# (397, 962)
# (x,y) : (433,998)
# (w,h) : (463,463)

# %%
for landmark in list_landmarks2:
    for point in landmark:
        cv2.circle(img_show3, point, 2, (0, 255, 255), -1)

img_show_rgb2 = cv2.cvtColor(img_show3, cv2.COLOR_BGR2RGB)
plt.imshow(img_show_rgb2)
plt.show()

# %%
# 스티커의 모양은 고양이 수염인데 아래와 같다. 
my_image_path2 = './cat-whiskers.png'
img_bgr2 = cv2.imread(my_image_path2)    # OpenCV로 이미지를 불러옵니다
img_show = img_bgr2.copy()      # 출력용 이미지를 따로 보관합니다
img_h, img_w, img_c = img_bgr2.shape
print(img_h, img_w, img_c)
plt.imshow(img_show)
plt.show()

# %%
my_image_path = './my_face3.jpg'
img_bgr3 = cv2.imread(my_image_path)    # OpenCV로 이미지를 불러옵니다
img_show3 = img_bgr3.copy()      # 출력용 이미지를 따로 보관합니다

sticker_area2 = img_bgr3[refined_y:refined_y +img_sticker2.shape[0], refined_x:refined_x+img_sticker2.shape[1]]
img_bgr3[refined_y:refined_y +img_sticker2.shape[0], refined_x:refined_x+img_sticker2.shape[1]] = \
    np.where(img_sticker2==255,sticker_area2,img_sticker2).astype(np.uint8)
plt.imshow(cv2.cvtColor(img_bgr3, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# 보다 시피 코의 위치가 어늦 난
